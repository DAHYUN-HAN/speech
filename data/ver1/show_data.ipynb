# %%
import librosa
import soundfile as sf
import matplotlib.pyplot as plt
import librosa.display
import numpy as np

import os
import IPython.display
import seaborn as sns

# %%
pad1d = lambda a, i: a[0: i] if a.shape[0] > i else np.hstack((a, np.zeros(i - a.shape[0])))
pad2d = lambda a, i: a[:, 0: i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0],i - a.shape[1]))))

# %%
wav = 'fire_dh.wav'
sr = librosa.get_samplerate(wav)

fire, sr = librosa.load(wav, sr=sr)
print('sr: ', sr)
print('wav shape: ', fire.shape)
print('length: ', fire.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=fire, rate=sr)
# Out:
# sr:  16000
# wav shape:  (12936,)
# length:  0.8085 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav = 'point.wav'
sr = librosa.get_samplerate(wav)

point, sr = librosa.load(wav, sr=sr)
print('sr: ', sr)
print('wav shape: ', point.shape)
print('length: ', point.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=point, rate=sr)
# Out:
# sr:  16000
# wav shape:  (13163,)
# length:  0.8226875 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav = 'non7.wav'
sr = librosa.get_samplerate(wav)

non7, sr = librosa.load(wav, sr=sr)
print('sr: ', sr)
print('wav shape: ', non7.shape)
print('length: ', non7.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=non7, rate=sr)
# Out:
# sr:  16000
# wav shape:  (15948,)
# length:  0.99675 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav = 'fire_dj.wav'
sr = librosa.get_samplerate(wav)

fire_dj, sr = librosa.load(wav, sr=sr)
print('sr: ', sr)
print('wav shape: ', fire_dj.shape)
print('length: ', fire_dj.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=fire_dj, rate=sr)
# Out:
# sr:  16000
# wav shape:  (10885,)
# length:  0.6803125 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
point = point[2000:]

# %%
wav = 'vitamin.wav'
sr = librosa.get_samplerate(wav)

vitamin, sr = librosa.load(wav, sr=sr)
print('sr: ', sr)
print('wav shape: ', vitamin.shape)
print('length: ', vitamin.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=vitamin, rate=sr)
# Out:
# sr:  16000
# wav shape:  (15014,)
# length:  0.938375 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav = 'd20.wav'
sr = librosa.get_samplerate(wav)

d20, sr = librosa.load(wav, sr=sr)
print('sr: ', sr)
print('wav shape: ', d20.shape)
print('length: ', d20.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=d20, rate=16000)
# Out:
# sr:  16000
# wav shape:  (17955,)
# length:  1.1221875 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(d20, sr=sr)

# %%
librosa.display.waveplot(non7, sr=sr)
librosa.display.waveplot(point, sr=sr, alpha=0)
librosa.display.waveplot(fire_dj, sr=sr, alpha=0)
librosa.display.waveplot(fire, sr=sr, alpha=0)
librosa.display.waveplot(sogogi[:-2000], sr=sr, alpha=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-6720decc49d7> in <module>
#       3 librosa.display.waveplot(fire_dj, sr=sr, alpha=0)
#       4 librosa.display.waveplot(fire, sr=sr, alpha=0)
# ----> 5 librosa.display.waveplot(sogogi[:-2000], sr=sr, alpha=0)
#
# NameError: name 'sogogi' is not defined

# %%
fire_dj_mfcc = librosa.feature.mfcc(fire_dj, sr=16000)
fire_dj_mfcc = librosa.util.normalize(fire_dj_mfcc)
fire_dj_padded_mfcc = pad2d(fire_dj_mfcc, 35)

fire_mfcc = librosa.feature.mfcc(fire, sr=16000)
#fire_mfcc = librosa.util.normalize(fire_mfcc)
fire_padded_mfcc = pad2d(fire_mfcc, 35)

point_mfcc = librosa.feature.mfcc(point, sr=16000)
point_mfcc = librosa.util.normalize(point_mfcc)
point_padded_mfcc = pad2d(point_mfcc, 35)

non7_mfcc = librosa.feature.mfcc(non7, sr=16000)
non7_mfcc = librosa.util.normalize(non7_mfcc)
non7_padded_mfcc = pad2d(non7_mfcc, 35)

vitamin_mfcc = librosa.feature.mfcc(vitamin, sr=16000)
vitamin_mfcc = librosa.util.normalize(vitamin_mfcc)
vitamin_padded_mfcc = pad2d(vitamin_mfcc, 35)

sogogi_mfcc = librosa.feature.mfcc(sogogi, sr=16000)
sogogi_mfcc = librosa.util.normalize(sogogi_mfcc)
sogogi_padded_mfcc = pad2d(sogogi_mfcc, 35)

d20_mfcc = librosa.feature.mfcc(d20, sr=16000)
#d20_mfcc = librosa.util.normalize(d20_mfcc)
d20_padded_mfcc = pad2d(d20_mfcc, 35)

librosa.display.specshow(fire_dj_padded_mfcc, y_axis='log', x_axis='time', sr=sr)
plt.colorbar()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-0efc8dff5bd3> in <module>
#      19 vitamin_padded_mfcc = pad2d(vitamin_mfcc, 35)
#      20
# ---> 21 sogogi_mfcc = librosa.feature.mfcc(sogogi, sr=16000)
#      22 sogogi_mfcc = librosa.util.normalize(sogogi_mfcc)
#      23 sogogi_padded_mfcc = pad2d(sogogi_mfcc, 35)
#
# NameError: name 'sogogi' is not defined

# %%
librosa.display.specshow(fire_padded_mfcc, y_axis='log', x_axis='time', sr=sr)
plt.colorbar()

# %%
librosa.display.specshow(point_padded_mfcc, y_axis='log', x_axis='time', sr=sr)
plt.colorbar()

# %%
librosa.display.specshow(non7_padded_mfcc, y_axis='log', x_axis='time', sr=sr)
plt.colorbar()

# %%
librosa.display.specshow(vitamin_padded_mfcc, y_axis='log', x_axis='time', sr=sr)
plt.colorbar()

# %%
librosa.display.specshow(sogogi_padded_mfcc, y_axis='log', x_axis='time', sr=sr)
plt.colorbar()

# %%
librosa.display.specshow(d20_padded_mfcc, y_axis='log', x_axis='time', sr=sr)
plt.colorbar()

# %%
wav = 'point.wav'
file_sr = librosa.get_samplerate(wav)

vitamin, sr = librosa.load(wav, sr=file_sr)
print('sr: ', sr)
print('wav shape: ', vitamin.shape)
print('length: ', vitamin.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=vitamin, rate=sr)
# Out:
# sr:  16000
# wav shape:  (13163,)
# length:  0.8226875 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wav = 'fire_dh.wav'
file_sr = librosa.get_samplerate(wav)

fire, sr = librosa.load(wav, sr=file_sr)
print('sr: ', sr)
print('wav shape: ', fire.shape)
print('length: ', fire.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=fire, rate=sr)
# Out:
# sr:  16000
# wav shape:  (12936,)
# length:  0.8085 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(vitamin, sr=sr)
librosa.display.waveplot(fire, sr=sr)

# %%
vitamin = librosa.resample(vitamin, 16000, 8000)

vitamin_mel_spectogram = librosa.feature.melspectrogram(vitamin)
vitamin_padded_mel_spectrogram = pad2d(vitamin_mel_spectogram, 50)

vitamin_mfcc = librosa.feature.mfcc(vitamin, sr=16000)
vitamin_padded_mfcc = pad2d(vitamin_mfcc, 50)

# %%
vitamin_mfcc = librosa.util.normalize(vitamin_mfcc)

plt.figure(figsize=(12, 4))
librosa.display.specshow(vitamin_mfcc,
                         y_axis='log', x_axis='time', sr=sr)
plt.colorbar()
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-79-aa3576d99720> in <module>
# ----> 1 vitamin_mfcc = librosa.util.normalize(vitamin_mfcc)
#       2
#       3 plt.figure(figsize=(12, 4))
#       4 librosa.display.specshow(vitamin_mfcc,
#       5                          y_axis='log', x_axis='time', sr=sr)
#
# NameError: name 'vitamin_mfcc' is not defined

# %%
# Load an example with vocals.
y, sr = librosa.load(wav, duration=240, sr=file_sr)

# And compute the spectrogram magnitude and phase
S_full, phase = librosa.magphase(librosa.stft(y))

# Plot a 5-second slice of the spectrum
idx = slice(*librosa.time_to_frames([0, 50], sr=sr))
plt.figure(figsize=(12, 4))
librosa.display.specshow(librosa.amplitude_to_db(S_full[:, idx], ref=np.max),
                         y_axis='log', x_axis='time', sr=sr)
plt.colorbar()
plt.tight_layout()

# %%
wav = 'non7.wav'
file_sr = librosa.get_samplerate(wav)

non, sr = librosa.load(wav, sr=file_sr)
print('sr: ', sr)
print('wav shape: ', non.shape)
print('length: ', non.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=non, rate=sr)
# Out:
# sr:  16000
# wav shape:  (15948,)
# length:  0.99675 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(non, sr=sr)

# %%
# Load an example with vocals.
y, sr = librosa.load(wav, sr=file_sr)

# And compute the spectrogram magnitude and phase
S_full, phase = librosa.magphase(librosa.stft(y))

# Plot a 5-second slice of the spectrum
idx = slice(*librosa.time_to_frames([0, 50], sr=sr))
plt.figure(figsize=(12, 4))
librosa.display.specshow(librosa.amplitude_to_db(S_full[:, idx], ref=np.max),
                         y_axis='log', x_axis='time', sr=sr)
plt.colorbar()
plt.tight_layout()

# %%
S = librosa.feature.melspectrogram(y, sr=sr, n_mels=128) 
 
log_S = librosa.logamplitude(S, ref_power=np.max)
plt.figure(figsize=(12, 4))
librosa.display.specshow(log_S, sr=sr, x_axis='time', y_axis='mel')
plt.title('mel power spectrogram')
plt.colorbar(format='%+02.0f dB')
plt.tight_layout()
plt.show()

# Load an example with vocals.
y, sr = librosa.load(wav, duration=240, sr=file_sr)

# And compute the spectrogram magnitude and phase
S_full, phase = librosa.magphase(librosa.stft(y))

# Plot a 5-second slice of the spectrum
idx = slice(*librosa.time_to_frames([0, 50], sr=sr))
plt.figure(figsize=(12, 4))
librosa.display.specshow(librosa.amplitude_to_db(S_full[:, idx], ref=np.max),
                         y_axis='log', x_axis='time', sr=sr)
plt.colorbar()
plt.tight_layout()

# %%
wav = 'fire_dh.wav'
file_sr = librosa.get_samplerate(wav)

fire, sr = librosa.load(wav, sr=file_sr)
print('sr: ', sr)
print('wav shape: ', fire.shape)
print('length: ', fire.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=fire, rate=sr)
# Out:
# sr:  16000
# wav shape:  (12936,)
# length:  0.8085 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(fire, sr=sr)

# %%
# Load an example with vocals.
y, sr = librosa.load(wav, sr=file_sr)

# And compute the spectrogram magnitude and phase
S_full, phase = librosa.magphase(librosa.stft(y))

# Plot a 5-second slice of the spectrum
idx = slice(*librosa.time_to_frames([0, 50], sr=sr))
plt.figure(figsize=(12, 4))
librosa.display.specshow(librosa.amplitude_to_db(S_full[:, idx], ref=np.max),
                         y_axis='log', x_axis='time', sr=sr)
plt.colorbar()
plt.tight_layout()

# %%
fire_mel_spectogram = librosa.feature.melspectrogram(fire)
fire_padded_mel_spectrogram = pad2d(fire_mel_spectogram, 50)

fire_mfcc = librosa.feature.mfcc(fire, sr=16000)
fire_padded_mfcc = pad2d(fire_mfcc, 50)

# %%
fire_mel_spectogram = librosa.util.normalize(fire_mel_spectogram)

plt.figure(figsize=(12, 4))
librosa.display.specshow(fire_mel_spectogram,
                         y_axis='log', x_axis='time', sr=sr)
plt.colorbar()
plt.tight_layout()

# %%
non_mel_spectogram = librosa.feature.melspectrogram(non)
non_padded_mel_spectrogram = pad2d(non_mel_spectogram, 50)

non_mfcc = librosa.feature.mfcc(non, sr=16000)
non_padded_mfcc = pad2d(non_mfcc, 50)

# %%
non_mel_spectogram = librosa.util.normalize(non_mel_spectogram)

plt.figure(figsize=(12, 4))
librosa.display.specshow(non_mel_spectogram,
                         y_axis='log', x_axis='time', sr=sr)
plt.colorbar()
plt.tight_layout()

# %%
plt.figure(figsize=(12, 4))
librosa.display.specshow(non_mfcc,
                         y_axis='log', x_axis='time', sr=sr)
plt.colorbar()
plt.tight_layout()

# %%
non_mfcc = librosa.util.normalize(non_mfcc)

plt.figure(figsize=(12, 4))
librosa.display.specshow(non_mfcc,
                         y_axis='log', x_axis='time', sr=sr)
plt.colorbar()
plt.tight_layout()

# %%
fire_mel_spectogram
# Out:
# array([[6.6928625e-02, 2.5556820e-02, 4.3528066e-03, ..., 9.5661730e-03,
#         3.4254643e-03, 1.8821770e-02],
#        [6.8566686e-01, 2.4005257e-01, 2.3619344e-02, ..., 2.8907489e-02,
#         1.2989377e-02, 1.7613089e-02],
#        [8.1052893e-01, 6.8800008e-01, 2.3677883e-01, ..., 7.2842441e-02,
#         1.3747363e-02, 2.2702746e-02],
#        ...,
#        [1.1394302e-02, 2.3156632e-02, 4.3416873e-02, ..., 1.3368475e-04,
#         5.4856988e-05, 4.3506952e-05],
#        [1.1927862e-02, 2.5339797e-02, 3.7509888e-02, ..., 4.2849497e-05,
#         1.7987571e-05, 8.0391765e-06],
#        [1.1520424e-03, 2.9957981e-03, 4.4485847e-03, ..., 4.2175898e-06,
#         1.7306432e-06, 7.1747945e-07]], dtype=float32)

# %%
min_level_db = -100
 
def _normalize(S):
    return np.clip((S - min_level_db) / -min_level_db, 0, 1)


norm_S = _normalize(log_S)
 
plt.figure(figsize=(12, 4))
librosa.display.specshow(norm_S, sr=sr, x_axis='time', y_axis='mel')
plt.title('norm mel power spectrogram')
plt.colorbar(format='%+0.1f dB')
plt.tight_layout()
plt.show()

# %%
norm_S = librosa.util.normalize(log_S)
 
plt.figure(figsize=(12, 4))
librosa.display.specshow(norm_S, sr=sr, x_axis='time', y_axis='mel')
plt.title('norm mel power spectrogram')
plt.colorbar(format='%+0.1f dB')
plt.tight_layout()
plt.show()

# %%
librosa.util.normalize

# %%
wav = 'snake10.wav'
file_sr = librosa.get_samplerate(wav)

non_snake, sr = librosa.load(wav, sr=file_sr)
print('sr: ', sr)
print('wav shape: ', non_snake.shape)
print('length: ', non_snake.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=non_snake, rate=sr)
# Out:
# sr:  44100
# wav shape:  (41653,)
# length:  0.9445124716553288 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(non_snake, sr=sr)

# %%
wav = 'fire_dh.wav'
file_sr = librosa.get_samplerate(wav)

fire, sr = librosa.load(wav, sr=file_sr)
print('sr: ', sr)
print('wav shape: ', fire.shape)
print('length: ', fire.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=fire, rate=sr)
# Out:
# sr:  16000
# wav shape:  (12936,)
# length:  0.8085 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(fire, sr=sr)

# %%
wav = 'fire_dj.wav'
file_sr = librosa.get_samplerate(wav)

fire_dj, sr = librosa.load(wav, sr=file_sr)
print('sr: ', sr)
print('wav shape: ', fire_dj.shape)
print('length: ', fire_dj.shape[0]/float(sr), 'secs')
IPython.display.Audio(data=fire_dj, rate=sr)
# Out:
# sr:  16000
# wav shape:  (10885,)
# length:  0.6803125 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(fire_dj, sr=sr)

# %%
wav = 'nega.wav'
file_sr = librosa.get_samplerate(wav)

nega, sr = librosa.load(wav, sr=file_sr)
print('sr: ', sr)
print('wav shape: ', nega.shape)
print('length: ', nega.shape[0]/float(sr), 'secs')
nega = nega[:13000]
IPython.display.Audio(data=nega, rate=sr)
# Out:
# sr:  16000
# wav shape:  (33334,)
# length:  2.083375 secs
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
librosa.display.waveplot(nega, sr=sr)

# %%
non_snake_mel_spectogram = librosa.feature.melspectrogram(non_snake)
non_snake_padded_mel_spectrogram = pad2d(non_snake_mel_spectogram, 50)

non_snake_mfcc = librosa.feature.mfcc(non_snake, sr=16000)
non_snake_padded_mfcc = pad2d(non_snake_mfcc, 50)

# %%
non_mel_spectogram = librosa.feature.melspectrogram(non)
non_padded_mel_spectrogram = pad2d(non_mel_spectogram, 50)
non_mfcc = librosa.feature.mfcc(non, sr=16000)
non_padded_mfcc = pad2d(non_mfcc, 50)

# %%
non_snake_mfcc.shape
# Out:
# (20, 82)

# %%
non_snake_mel_spectogram = librosa.feature.melspectrogram(non_snake)
non_snake_padded_mel_spectrogram = pad2d(non_snake_mel_spectogram, 50)

non_snake_mfcc = librosa.feature.mfcc(non_snake, sr=16000)
non_snake_padded_mfcc = pad2d(non_snake_mfcc, 50)

# %%
fire_mel_spectogram = librosa.feature.melspectrogram(fire)
fire_padded_mel_spectrogram = pad2d(fire_mel_spectogram, 50)

fire_mfcc = librosa.feature.mfcc(fire, sr=16000)
fire_padded_mfcc = pad2d(fire_mfcc, 50)

# %%
fire_dj_mel_spectogram = librosa.feature.melspectrogram(fire_dj)
fire_dj_padded_mel_spectrogram = pad2d(fire_dj_mel_spectogram, 50)

fire_dj_mfcc = librosa.feature.mfcc(fire_dj, sr=16000)
fire_dj_padded_mfcc = pad2d(fire_dj_mfcc, 50)

# %%
nega_mel_spectogram = librosa.feature.melspectrogram(nega)
nega_padded_mel_spectrogram = pad2d(nega_mel_spectogram, 50)

nega_mfcc = librosa.feature.mfcc(nega, sr=16000)
nega_padded_mfcc = pad2d(nega_mfcc, 50)

# %%
#탕수육
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(non_mfcc)
# Out:
# <AxesSubplot:>

# %%
#뱀이다
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(non_snake_mfcc)
# Out:
# <AxesSubplot:>

# %%
#불이야
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(fire_mfcc)
# Out:
# <AxesSubplot:>

# %%
fire_mfcc.shape
# Out:
# (20, 13)

# %%
fire_dj_mfcc.shape
# Out:
# (20, 22)

# %%
fire.shape
# Out:
# (12936,)

# %%
fire = librosa.resample(fire, 16000, 8000)
fire_mel_spectogram = librosa.feature.melspectrogram(fire)
fire_padded_mel_spectrogram = pad2d(fire_mel_spectogram, 50)

fire_mfcc = librosa.feature.mfcc(fire, sr=16000, n_mfcc = 20)
fire_padded_mfcc = pad2d(fire_mfcc, 50)

# %%
fire_mfcc.shape
# Out:
# (40, 26)

# %%
#배경음
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(nega_mfcc)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(non_bi_mfcc)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(fire_dj_mfcc)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(non_mel_spectogram)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(non_snake_mel_spectogram)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(non_bi_mel_spectogram)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(fire_mel_spectogram)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(fire_dj_mel_spectogram)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots(figsize=(20,5))
sns.heatmap(nega_mel_spectogram)
# Out:
# <AxesSubplot:>

# %%
import scipy.signal as signal
import math
import librosa
import numpy as np

def wav_fft(file_name):
    print("fft start")
    audio_sample, sampling_rate = librosa.load(file_name, sr = None)        
    fft_result = librosa.stft(audio_sample, n_fft=1024, hop_length=512, win_length = 1024, window=signal.hann).T                    
    mag, phase = librosa.magphase(fft_result)                    
    print("fft end")
    return mag

#normalize_function
min_level_db = -100
def _normalize(S):
    return np.clip((S-min_level_db)/(-min_level_db), 0, 1)

# %%
mag_db = librosa.amplitude_to_db(fire)
mag_n = _normalize(mag_db)

# %%
mag_n.T
# Out:
# array([0.57149243, 0.5771901 , 0.5273677 , ..., 0.52978057, 0.52297676,
#        0.19999734], dtype=float32)

# %%
import matplotlib.pyplot as plt
import librosa.display

librosa.display.specshow(mag_n, y_axis='linear', x_axis='time', sr=sampling_rate)
plt.title('FFT result')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-217-1a1a91b08aac> in <module>
#       2 import librosa.display
#       3
# ----> 4 librosa.display.specshow(mag_n, y_axis='linear', x_axis='time', sr=sampling_rate)
#       5 plt.title('FFT result')
#       6 plt.show()
#
# NameError: name 'sampling_rate' is not defined

# %%
pad2d = lambda a, i: a[:, 0: i] if a.shape[1] > i else np.hstack((a, np.zeros((a.shape[0],i - a.shape[1]))))

# %%
def padding(a, i) :
    if (a.shape[1] >= i) :
        return a[:, 0:i]
    else :
        difference = i-a.shape[1]
        zeros = np.random.randint(difference+1)
        
        #print(zeros, difference-zeros)
        
        first = np.zeros((a.shape[0], zeros))
        second = np.zeros((a.shape[0], difference - zeros))
        
        new = np.hstack((first, a))
        new = np.hstack((new, second))
        
        return new

# %%
TEST_DATA_DIR = 'C:/Users/JLK/speech/data/final_oldver/final_ver2/test/'
padding_list=[]
file_name = []
for fname in os.listdir(TEST_DATA_DIR):
    try:
        if '.wav' not in fname or 'dima' in fname:
            continue
        wav, sr = librosa.load(TEST_DATA_DIR + fname, sr=16000)
            
        mfcc = librosa.feature.mfcc(wav, sr=16000)
        padded_mfcc = pad2d(mfcc, 63)
        padding_list.append(padded_mfcc)
        file_name.append(fname)
    except Exception as e:
        print(fname, e)
        raise

# %%
i=449
librosa.display.specshow(padding_list[i], y_axis='log', x_axis='time', sr=sr)
print(file_name[i])
plt.colorbar()
# Out:
# 0.8_bg_6_dj1.wav

# %%
librosa.display.specshow(padding_list[9], y_axis='log', x_axis='time', sr=sr)
print(file_name[9])
plt.colorbar()
# Out:
# 0.21_bg_2982_dj6.wav
